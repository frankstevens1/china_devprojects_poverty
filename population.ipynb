# %%
import pandas as pd

# %%
population = pd.read_csv("gdl/GDL-Population-size-in-millions-data.csv", skipinitialspace=True)
population
# Out:
#           Country ISO_Code   Level  GDLCODE  \
# 0     Afghanistan      AFG  Subnat  AFGr101
# 1     Afghanistan      AFG  Subnat  AFGr102
# 2     Afghanistan      AFG  Subnat  AFGr103
# 3     Afghanistan      AFG  Subnat  AFGr104
# 4     Afghanistan      AFG  Subnat  AFGr105
# ...           ...      ...     ...      ...
# 1760     Zimbabwe      ZWE  Subnat  ZWEr104
# 1761     Zimbabwe      ZWE  Subnat  ZWEr108
# 1762     Zimbabwe      ZWE  Subnat  ZWEr105
# 1763     Zimbabwe      ZWE  Subnat  ZWEr106
# 1764     Zimbabwe      ZWE  Subnat  ZWEr107
#
#                                                  Region  1990  1991  1992  \
# 0     Central (Kabul Wardak Kapisa Logar Parwan Panj...  1.98  2.12  2.31
# 1                   Central Highlands (Bamyan Daikundi)  0.42  0.45  0.49
# 2              East (Nangarhar Kunar Laghman Nooristan)  1.38  1.48  1.61
# 3       North (Samangan Sar-e-Pul Balkh Jawzjan Faryab)  1.72  1.84  2.00
# ...

# %%
population = pd.melt(population, id_vars=['Country', 'ISO_Code', 'Level', 'GDLCODE', 'Region'],var_name='year', value_name='population')
population
# Out:
#            Country ISO_Code   Level  GDLCODE  \
# 0      Afghanistan      AFG  Subnat  AFGr101
# 1      Afghanistan      AFG  Subnat  AFGr102
# 2      Afghanistan      AFG  Subnat  AFGr103
# 3      Afghanistan      AFG  Subnat  AFGr104
# 4      Afghanistan      AFG  Subnat  AFGr105
# ...            ...      ...     ...      ...
# 51180     Zimbabwe      ZWE  Subnat  ZWEr104
# 51181     Zimbabwe      ZWE  Subnat  ZWEr108
# 51182     Zimbabwe      ZWE  Subnat  ZWEr105
# 51183     Zimbabwe      ZWE  Subnat  ZWEr106
# 51184     Zimbabwe      ZWE  Subnat  ZWEr107
#
#                                                   Region  year  population
# 0      Central (Kabul Wardak Kapisa Logar Parwan Panj...  1990        1.98
# 1                    Central Highlands (Bamyan Daikundi)  1990        0.42
# 2               East (Nangarhar Kunar Laghman Nooristan)  1990        1.38
# 3        North (Samangan Sar-e-Pul Balkh Jawzjan Faryab)  1990        1.72
# ...

# %%
population.to_csv('population.csv')
