# %%
import pandas as pd
data = pd.read_csv("dataset_v2.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  GDLCODE  year  iwipov50_real  transport  trans2y  trans3y  \
# 0           0  AFGr101  2015          0.368        NaN      0.0      0.0
# 1           1  AFGr102  2015          0.765        NaN      0.0      0.0
# 2           2  AFGr103  2015          0.779        NaN      0.0      0.0
# 3           3  AFGr104  2015          0.376        NaN      0.0      0.0
# 4           4  AFGr105  2015          0.616        NaN      0.0      0.0
#
#    trans4y  trans5y   prev  prev_year      unit_of_analysis  trans2y_d  \
# 0      0.0      0.0  0.519       2010  AFGr101_2010_to_2015          0
# 1      0.0      0.0  0.831       2010  AFGr102_2010_to_2015          0
# 2      0.0      0.0  0.788       2010  AFGr103_2010_to_2015          0
# 3      0.0      0.0  0.778       2010  AFGr104_2010_to_2015          0
# 4      0.0      0.0  0.710       2010  AFGr105_2010_to_2015          0
#
#    trans3y_d  trans4y_d  trans5y_d  change_iwipov50  \
# ...
